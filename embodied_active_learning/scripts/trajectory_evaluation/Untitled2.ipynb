# %%
from rrt import RRTStar

# %%
allpts = [((319, 1083),(319, 812)),((319, 812),(159, 1083)),((159, 1083),(319, 677)),((319, 677),(638, 677)),((638, 677),(159, 948)),((159, 948),(319, 270)),((319, 270),(319, 541)),((319, 541),(478, 677)),((478, 677),(319, 948))]

# %%
p = 0*map_occupied
for (s,g) in allpts:

    
    plt.imshow(map_occupied)
    for (x,y) in path:
        x = int(x)
        y = int(y)
        p[x-10:x+10,y-10:y+10] = 1
    plt.imshow(p, alpha = 0.5)
    plt.show()
# Out:
# reached max iteration
# reached max iteration
# reached max iteration
# reached max iteration
# reached max iteration
# reached max iteration
# reached max iteration
# reached max iteration
# reached max iteration
